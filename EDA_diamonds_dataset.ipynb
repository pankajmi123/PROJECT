# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
diamond = pd.read_excel(r"C:\Users\dell\Desktop\.ipynb_checkpoints\Diamonds.xlsx")

# %%
diamond.head()
# Out:
#    carat      cut color clarity  depth  table price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0   326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0   326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0   327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0   334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0   335  4.34  4.35  2.75

# %%
diamond.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53948 entries, 0 to 53947
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53947 non-null  float64
#  1   cut      53947 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53946 non-null  object
#  4   depth    53903 non-null  float64
#  5   table    53946 non-null  float64
#  6   price    53946 non-null  object
#  7   x        53946 non-null  float64
#  8   y        53946 non-null  float64
#  9   z        53941 non-null  float64
# dtypes: float64(6), object(4)
# memory usage: 4.1+ MB

# %% [markdown]
# We observe that we have missing values in the dataset and the price column is stored as object

# %%
diamond.isnull().sum()
# Out:
# carat       1
# cut         1
# color       8
# clarity     2
# depth      45
# table       2
# price       2
# x           2
# y           2
# z           7
# dtype: int64

# %%
diamond[diamond.carat.isnull()]
# Out:
#        carat  cut color clarity  depth  table price   x   y   z
# 53885    NaN  NaN   NaN     NaN    NaN    NaN   NaN NaN NaN NaN

# %%
diamond.dropna(how='all',inplace=True)

# %%
diamond.isnull().sum()
# Out:
# carat       0
# cut         0
# color       7
# clarity     1
# depth      44
# table       1
# price       1
# x           1
# y           1
# z           6
# dtype: int64

# %%
diamond[diamond.color.isnull()]
# Out:
#        carat        cut color clarity  depth  table price     x     y     z
# 19      0.30  Very Good   NaN     SI1   62.7   59.0   351  4.21  4.27  2.66
# 18109   1.56    Premium   NaN     VS2   60.8   59.0  7326  7.56  7.51  4.58
# 43474   0.50       Good   NaN     VS2   63.1   61.0  1419  5.00  5.05  3.17
# 53895   0.71      Ideal   NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN
# 53920   0.76      Ideal   NaN    VVS1   62.2   55.0  2753  5.89  5.87  3.66
# 53927   0.71      Ideal   NaN     SI1   61.9   56.0  2756  5.71  5.73  3.54
# 53941   0.70  Very Good   NaN     VS2   61.2   59.0  2757  5.69  5.72  3.49

# %%
diamond.drop(index=53895,inplace=True)

# %%
diamond.isnull().sum()
# Out:
# carat       0
# cut         0
# color       6
# clarity     0
# depth      43
# table       0
# price       0
# x           0
# y           0
# z           5
# dtype: int64

# %%
diamond.color.value_counts()
# Out:
# G    11291
# E     9795
# F     9542
# H     8305
# D     6780
# I     5420
# J     2807
# Name: color, dtype: int64

# %%
diamond.color.fillna("G",inplace=True)

# %%
diamond.isnull().sum()
# Out:
# carat       0
# cut         0
# color       0
# clarity     0
# depth      43
# table       0
# price       0
# x           0
# y           0
# z           5
# dtype: int64

# %%
diamond[diamond.depth.isnull()]
# Out:
#        carat        cut color clarity  depth  table price     x     y     z
# 20      0.30       Good     I     SI2    NaN   56.0   351  4.26  4.30  2.71
# 21      0.23  Very Good     E     VS2    NaN   55.0   352  3.85  3.92  2.48
# 26      0.24    Premium     I     VS1    NaN   57.0   355  3.97  3.94  2.47
# 27      0.30  Very Good     J     VS2    NaN   57.0   357  4.28  4.30  2.67
# 45      0.29    Premium     F     SI1    NaN   58.0   403  4.24  4.26  2.65
# 46      0.32  Very Good     H     SI2    NaN   55.0   403  4.35  4.42  2.71
# 47      0.32       Good     H     SI2    NaN   56.0   403  4.36  4.38  2.79
# 48      0.25  Very Good     E     VS2    NaN   60.0   404  4.00  4.03  2.54
# 49      0.29  Very Good     H     SI2    NaN   60.0   404  4.33  4.37  2.64
# 50      0.24  Very Good     F     SI1    NaN   61.0   404  4.02  4.03  2.45
# 51      0.23      Ideal     G     VS1    NaN   54.0   404  3.93  3.95  2.44
# ...

# %%
diamond.describe()
# Out:
#               carat         depth         table             x             y  \
# count  53946.000000  53903.000000  53946.000000  53946.000000  53946.000000
# mean       0.797934     61.749678     57.457218      5.731163      5.734534
# std        0.473986      1.432615      2.234460      1.121700      1.142073
# min        0.200000     43.000000     43.000000      0.000000      0.000000
# 25%        0.400000     61.000000     56.000000      4.710000      4.720000
# 50%        0.700000     61.800000     57.000000      5.700000      5.710000
# 75%        1.040000     62.500000     59.000000      6.540000      6.540000
# max        5.010000     79.000000     95.000000     10.740000     58.900000
#
#                   z
# count  53941.000000
# mean       3.538740
# std        0.705674
# min        0.000000
# 25%        2.910000
# 50%        3.530000
# 75%        4.040000
# max       31.800000

# %% [markdown]
# We see that x, y and z columns have a min value of 0 which doesn't make sense. There seems to be some faulty data

# %%
diamond.corr()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_62752\2000980190.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   diamond.corr()
#           carat     depth     table         x         y         z
# carat  1.000000  0.028226  0.181606  0.975093  0.951721  0.953385
# depth  0.028226  1.000000 -0.295548 -0.025243 -0.029295  0.094934
# table  0.181606 -0.295548  1.000000  0.195334  0.183750  0.150997
# x      0.975093 -0.025243  0.195334  1.000000  0.974701  0.970771
# y      0.951721 -0.029295  0.183750  0.974701  1.000000  0.952004
# z      0.953385  0.094934  0.150997  0.970771  0.952004  1.000000

# %%
diamond.depth.fillna(diamond.depth.mean(),inplace=True)

# %%
diamond.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          5
# dtype: int64

# %%
diamond.depth.mean()
# Out:
# 61.749678125521775

# %%
diamond[diamond.z.isnull()]
# Out:
#        carat        cut color clarity  depth  table  price     x     y   z
# 8162    0.70  Very Good     D    VVS1   63.4   59.0   4362  5.63  5.64 NaN
# 10104   0.73  Very Good     D    VVS1   61.8   61.0   4716  5.70  5.73 NaN
# 11054   0.28  Very Good     D    VVS1   60.3   62.0    596  4.22  4.24 NaN
# 23758   1.06  Very Good     D    VVS1   61.8   57.0  11815  6.49  6.52 NaN
# 23839   1.01  Very Good     D    VVS1   63.9   56.0  11923  6.32  6.36 NaN

# %% [markdown]
# Since we have a high correlation between x and z columns, we can take advantage of this insight to predict the missing z values

# %%
diamond.x.mean()/diamond.z.mean()
# Out:
# 1.6195489198652102

# %%
diamond.z.fillna(diamond.x*diamond.z.mean()/diamond.x.mean(),inplace=True)

# %%
diamond.x*diamond.z.mean()/diamond.x.mean()
# Out:
# 0        2.439615
# 1        2.402557
# 2        2.501377
# 3        2.594020
# 4        2.680488
#            ...
# 53937    3.514280
# 53938    3.495751
# 53939    3.798387
# 53940    3.600747
# 53941    3.514280
# Name: x, Length: 53787, dtype: float64

# %%
diamond.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
diamond[diamond.x==0]
# Out:
#        carat        cut color clarity  depth  table  price    x     y    z
# 11182   1.07      Ideal     F     SI2   61.6   56.0   4954  0.0  6.62  0.0
# 11963   1.00  Very Good     H     VS2   63.3   53.0   5139  0.0  0.00  0.0
# 15951   1.14       Fair     G     VS1   57.5   67.0   6381  0.0  0.00  0.0
# 24520   1.56      Ideal     G     VS2   62.2   54.0  12800  0.0  0.00  0.0
# 26243   1.20    Premium     D    VVS1   62.1   59.0  15686  0.0  0.00  0.0
# 27429   2.25    Premium     H     SI2   62.8   59.0  18034  0.0  0.00  0.0
# 49556   0.71       Good     F     SI2   64.1   60.0   2130  0.0  0.00  0.0
# 49557   0.71       Good     F     SI2   64.1   60.0   2130  0.0  0.00  0.0

# %%
diamond.drop(index=[11182,11963,15951,24520,26243,27429,49556,49557],inplace=True)

# %%
diamond[diamond.x==0]
# Out:
# Empty DataFrame
# Columns: [carat, cut, color, clarity, depth, table, price, x, y, z]
# Index: []

# %%
diamond.describe()
# Out:
#               carat         depth         table             x             y  \
# count  53938.000000  53938.000000  53938.000000  53938.000000  53938.000000
# mean       0.797873     61.749609     57.457064      5.732013      5.735262
# std        0.473960      1.431937      2.234034      1.119609      1.140281
# min        0.200000     43.000000     43.000000      3.730000      3.680000
# 25%        0.400000     61.000000     56.000000      4.710000      4.720000
# 50%        0.700000     61.800000     57.000000      5.700000      5.710000
# 75%        1.040000     62.500000     59.000000      6.540000      6.540000
# max        5.010000     79.000000     95.000000     10.740000     58.900000
#
#                   z
# count  53938.000000
# mean       3.539262
# std        0.704392
# min        0.000000
# 25%        2.910000
# 50%        3.530000
# 75%        4.040000
# max       31.800000

# %%
list(diamond[diamond.z==0].index)
# Out:
# [2207,
#  2314,
#  4791,
#  5471,
#  10167,
#  13601,
#  24394,
#  26123,
#  27112,
#  27503,
#  27739,
#  51506]

# %%
diamond.loc[diamond.z==0,"z"] = diamond.x*diamond.z.mean()/diamond.x.mean()

# %%
diamond.describe()
# Out:
#               carat         depth         table             x             y  \
# count  53938.000000  53938.000000  53938.000000  53938.000000  53938.000000
# mean       0.797873     61.749609     57.457064      5.732013      5.735262
# std        0.473960      1.431937      2.234034      1.119609      1.140281
# min        0.200000     43.000000     43.000000      3.730000      3.680000
# 25%        0.400000     61.000000     56.000000      4.710000      4.720000
# 50%        0.700000     61.800000     57.000000      5.700000      5.710000
# 75%        1.040000     62.500000     59.000000      6.540000      6.540000
# max        5.010000     79.000000     95.000000     10.740000     58.900000
#
#                   z
# count  53938.000000
# mean       3.540284
# std        0.702636
# min        1.070000
# 25%        2.910000
# 50%        3.530000
# 75%        4.040000
# max       31.800000

# %%
diamond.describe()
# Out:
#               carat         depth         table             x             y  \
# count  53938.000000  53938.000000  53938.000000  53938.000000  53938.000000
# mean       0.797873     61.749609     57.457064      5.732013      5.735262
# std        0.473960      1.431937      2.234034      1.119609      1.140281
# min        0.200000     43.000000     43.000000      3.730000      3.680000
# 25%        0.400000     61.000000     56.000000      4.710000      4.720000
# 50%        0.700000     61.800000     57.000000      5.700000      5.710000
# 75%        1.040000     62.500000     59.000000      6.540000      6.540000
# max        5.010000     79.000000     95.000000     10.740000     58.900000
#
#                   z
# count  53938.000000
# mean       3.540284
# std        0.702636
# min        1.070000
# 25%        2.910000
# 50%        3.530000
# 75%        4.040000
# max       31.800000

# %%
diamond.price.str.isnumeric().value_counts()
# Out:
# False    5
# Name: price, dtype: int64

# %%
diamond[diamond.price.str.isnumeric()==False]
# Out:
#        carat        cut color clarity  depth  table  \
# 32      0.23  Very Good     E     VS1   60.7   59.0
# 80      0.26  Very Good     E    VVS1   63.4   59.0
# 23161   1.54    Premium     H     VS2   61.0   60.0
# 33067   0.32      Ideal     H      IF   61.6   55.0
# 50172   0.50  Very Good     F      IF   59.7   60.0
#
#                                                    price     x     y     z
# 32     ?                                             ...  3.97  4.01  2.42
# 80                                                     ?  4.00  4.04  2.55
# 23161                                                  ?  7.46  7.42  4.54
# 33067                                                  ?  4.41  4.42  2.72
# 50172                                                  ?  5.18  5.24  3.11

# %%
# This basically converts every value to muneric and at places where it is not possible will be replaced with NaNs
diamond.price=pd.to_numeric(diamond.price,errors="coerce")

# %%
diamond.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53938 entries, 0 to 53947
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53938 non-null  float64
#  1   cut      53938 non-null  object
#  2   color    53938 non-null  object
#  3   clarity  53938 non-null  object
#  4   depth    53938 non-null  float64
#  5   table    53938 non-null  float64
#  6   price    53933 non-null  float64
#  7   x        53938 non-null  float64
#  8   y        53938 non-null  float64
#  9   z        53938 non-null  float64
# dtypes: float64(7), object(3)
# memory usage: 6.5+ MB

# %%
diamond.corr()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_62752\2000980190.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   diamond.corr()
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.028217  0.181646  0.921603  0.977763  0.953988  0.961044
# depth  0.028217  1.000000 -0.295312 -0.010696 -0.025042 -0.029087  0.094890
# table  0.181646 -0.295312  1.000000  0.127144  0.196120  0.184520  0.152529
# price  0.921603 -0.010696  0.127144  1.000000  0.887215  0.867857  0.868194
# x      0.977763 -0.025042  0.196120  0.887215  1.000000  0.974933  0.975451
# y      0.953988 -0.029087  0.184520  0.867857  0.974933  1.000000  0.956770
# z      0.961044  0.094890  0.152529  0.868194  0.975451  0.956770  1.000000

# %%
diamond.price.fillna(diamond.carat*diamond.price.mean()/diamond.carat.mean(),inplace=True)

# %%
diamond.price.mean()/diamond.carat.mean()
# Out:
# 4929.495260063504

# %%
diamond.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53938 entries, 0 to 53947
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53938 non-null  float64
#  1   cut      53938 non-null  object
#  2   color    53938 non-null  object
#  3   clarity  53938 non-null  object
#  4   depth    53938 non-null  float64
#  5   table    53938 non-null  float64
#  6   price    53938 non-null  float64
#  7   x        53938 non-null  float64
#  8   y        53938 non-null  float64
#  9   z        53938 non-null  float64
# dtypes: float64(7), object(3)
# memory usage: 6.5+ MB

# %% [markdown]
# ### Checking for duplicates

# %%
diamond.duplicated().sum()
# Out:
# 151

# %% [markdown]
# There are 150 rows with duplicates which need to be removed

# %%
diamond[diamond.duplicated()]
# Out:
#        carat        cut color clarity  depth  table   price     x     y     z
# 1005    0.79      Ideal     G     SI1   62.3   57.0  2898.0  5.90  5.85  3.66
# 1006    0.79      Ideal     G     SI1   62.3   57.0  2898.0  5.90  5.85  3.66
# 1007    0.79      Ideal     G     SI1   62.3   57.0  2898.0  5.90  5.85  3.66
# 1008    0.79      Ideal     G     SI1   62.3   57.0  2898.0  5.90  5.85  3.66
# 2025    1.52       Good     E      I1   57.3   58.0  3105.0  7.53  7.42  4.28
# ...      ...        ...   ...     ...    ...    ...     ...   ...   ...   ...
# 53943   0.72      Ideal     D     SI1   60.8   57.0  2757.0  5.75  5.76  3.50
# 53944   0.72       Good     D     SI1   63.1   55.0  2757.0  5.69  5.75  3.61
# 53945   0.70  Very Good     D     SI1   62.8   60.0  2757.0  5.66  5.68  3.56
# 53946   0.86    Premium     H     SI2   61.0   58.0  2757.0  6.15  6.12  3.74
# 53947   0.75      Ideal     D     SI2   62.2   55.0  2757.0  5.83  5.87  3.64
#
# [151 rows x 10 columns]

# %%
# Dropping duplicates
diamond.drop_duplicates(inplace=True)

# %%
diamond.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53787 entries, 0 to 53941
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53787 non-null  float64
#  1   cut      53787 non-null  object
#  2   color    53787 non-null  object
#  3   clarity  53787 non-null  object
#  4   depth    53787 non-null  float64
#  5   table    53787 non-null  float64
#  6   price    53787 non-null  float64
#  7   x        53787 non-null  float64
#  8   y        53787 non-null  float64
#  9   z        53787 non-null  float64
# dtypes: float64(7), object(3)
# memory usage: 4.5+ MB

# %% [markdown]
# We finally have a clean dataset wherein all the missing values in the columns have been handled appropraitely, removed all the duplicates and made sure the variables are stored correctly

# %%
diamond.cut.value_counts()
# Out:
# Ideal        21485
# Premium      13746
# Very Good    12069
# Good          4890
# Fair          1597
# Name: cut, dtype: int64

# %%
diamond.clarity.value_counts()
# Out:
# SI1     13031
# VS2     12228
# SI2      9147
# VS1      8155
# VVS2     5056
# VVS1     3646
# IF       1784
# I1        740
# Name: clarity, dtype: int64

# %%
diamond.color.value_counts()
# Out:
# G    11265
# E     9774
# F     9518
# H     8270
# D     6754
# I     5405
# J     2801
# Name: color, dtype: int64

# %%
diamond.groupby("cut").price.mean()
# Out:
# cut
# Fair         4340.677520
# Good         3919.486912
# Ideal        3462.314593
# Premium      4581.454710
# Very Good    3980.959974
# Name: price, dtype: float64

# %% [markdown]
# Ideal seems to be the cheapest and premium cut diamonds are the costliest

# %%
pd.pivot_table(data=diamond,index="clarity",values="price",aggfunc="mean")
# Out:
#                price
# clarity
# I1       3925.275676
# IF       2871.134604
# SI1      3996.260686
# SI2      5056.368099
# VS1      3841.389637
# VS2      3926.527760
# VVS1     2523.193180
# VVS2     3286.532437

# %% [markdown]
# SI2 seems to be the most premium cut

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data=diamond,x="color",y="price")
plt.show()

# %% [markdown]
# Color J diamonds seem to have a higher average price of all the other colors

# %%
plt.figure(figsize=(12,8))
sns.heatmap(diamond.corr(),annot=True)
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_62752\3926878171.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(diamond.corr(),annot=True)

# %% [markdown]
# Price is highly correlated with carat, x, y and z columns which is to be expected

# %%
sns.pairplot(diamond)

# %%
diamond.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53787 entries, 0 to 53941
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53787 non-null  float64
#  1   cut      53787 non-null  object
#  2   color    53787 non-null  object
#  3   clarity  53787 non-null  object
#  4   depth    53787 non-null  float64
#  5   table    53787 non-null  float64
#  6   price    53787 non-null  float64
#  7   x        53787 non-null  float64
#  8   y        53787 non-null  float64
#  9   z        53787 non-null  float64
# dtypes: float64(7), object(3)
# memory usage: 4.5+ MB

# %%
sns.distplot(diamond.price)
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_62752\1342567183.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(diamond.price)

# %% [markdown]
# We see that the price column is highly skewed to the right

# %% [markdown]
# - Univariate - analysing individual columns
# - Bivariate - Relationship between two columns
# - Multivariate - More than 2 columns

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=diamond, x="carat",y="price",hue="color")
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.jointplot(data=diamond, x="carat",y="price",kind="reg")
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
sns.countplot(x="cut",data=diamond)

plt.subplot(1,3,2)
sns.countplot(x="color",data=diamond)

plt.subplot(1,3,3)
sns.countplot(x="clarity",data=diamond)
plt.show()

# %%
diamond.sample(n=100) # samples a dataset
# Out:
#        carat      cut color clarity  depth  table   price     x     y     z
# 3634    0.71    Ideal     G     VS1   60.7   57.0  3431.0  5.76  5.80  3.51
# 27852   0.31    Ideal     G     VS2   61.5   56.0   652.0  4.34  4.36  2.68
# 2303    0.74     Good     E     VS2   63.5   56.0  3163.0  5.75  5.80  3.67
# 43697   0.50     Good     F     VS2   63.6   57.0  1436.0  5.03  5.07  3.21
# 50481   0.55    Ideal     F    VVS2   62.0   55.0  2268.0  5.26  5.29  3.27
# ...      ...      ...   ...     ...    ...    ...     ...   ...   ...   ...
# 8499    1.07    Ideal     J     SI1   62.4   56.0  4422.0  6.52  6.56  4.08
# 44831   0.51  Premium     E     SI1   61.7   59.0  1624.0  5.12  5.09  3.15
# 4751    1.00  Premium     J     VS2   60.7   61.0  3685.0  6.50  6.41  3.92
# 37851   0.46     Fair     G     VS2   65.3   56.0  1002.0  4.83  4.76  3.13
# 44563   0.52     Good     D     SI1   63.7   55.0  1605.0  5.12  5.09  3.25
#
# [100 rows x 10 columns]

# %%
plt.figure(figsize=(15,10))
sns.catplot(data=diamond,x="cut",y="price",kind="violin")
plt.show()
